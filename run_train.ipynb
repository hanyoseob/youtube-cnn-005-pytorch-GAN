# %%
# !python3 "/content/drive/My Drive/YouTube/youtube-cnn-005-pytorch-GAN/train.py" \
          --batch_size 64 \
          --data_dir "/content/drive/My Drive/datasets/img_align_celeba" \
          --ckpt_dir "/content/drive/My Drive/YouTube/youtube-cnn-005-pytorch-GAN/checkpoints" \
          --log_dir "/content/drive/My Drive/YouTube/youtube-cnn-005-pytorch-GAN/log" \
          --result_dir "/content/drive/My Drive/YouTube/youtube-cnn-005-pytorch-GAN/result"
# Out:
# mode: train
# learning rate: 2.0000e-04
# batch size: 64
# number of epoch: 300
# task: GAN
# opts: ['bilinear', array([4., 0.])]
# network: DCGAN
# learning type: plain
# data dir: /content/drive/My Drive/datasets/img_align_celeba
# ckpt dir: /content/drive/My Drive/YouTube/youtube-cnn-005-pytorch-GAN/checkpoints
# log dir: /content/drive/My Drive/YouTube/youtube-cnn-005-pytorch-GAN/log
# result dir: /content/drive/My Drive/YouTube/youtube-cnn-005-pytorch-GAN/result
# device: cuda
# initialize network with normal
# initialize network with normal
# 2020-04-18 01:31:00.388077: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Traceback (most recent call last):
#   File "/content/drive/My Drive/YouTube/youtube-cnn-005-pytorch-GAN/train.py", line 226, in <module>
#     for batch, data in enumerate(loader_train, 1):
#   File "/usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py", line 345, in __next__
# ...
